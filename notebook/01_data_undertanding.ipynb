# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import display

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 100)
pd.set_option("display.width", 1000)
pd.set_option("display.max_colwidth", None)
plt.rcParams.update({'figure.figsize': (12, 6),'figure.dpi':120})

# %%
products = pd.read_csv("../data/raw/products.csv")
orders = pd.read_csv("../data/raw/orders.csv")
order_items = pd.read_csv("../data/raw/order_items.csv")
order_item_refunds = pd.read_csv("../data/raw/order_item_refunds.csv")
website_pageviews = pd.read_csv("../data/raw/website_pageviews.csv")
website_sessions = pd.read_csv("../data/raw/website_sessions.csv")

# %%
datasets = {
    "products"          : products,
    "orders"            : orders,
    "order_items"       : order_items,
    "order_item_refunds": order_item_refunds,
    "website_pageviews" : website_pageviews,
    "website_sessions"  : website_sessions
}

# %%
for name,df in datasets.items():
    print("-" * 60)
    print(f"{name}".upper())
    print("-" * 60)
    
    display(df.head())
    
    print(f'Shape : {df.shape}')
    
    print("\nData Types:")
    display(df.dtypes.to_frame(name = "Data Type"))
    
    print("\nDuplicate:")
    display(df.duplicated().sum())
    
    print("\nMissing Values:")
    display(df.isnull().sum().to_frame(name = "Missing Count"))
    
    print("\nMemory Usage (MB):")
    memory_mb = (
        df.memory_usage(deep=True).sum()
        / 1024**2
    )

    print(f"{memory_mb:.2f} MB")

    print("\n")
# Out:
# ------------------------------------------------------------
# PRODUCTS
# ------------------------------------------------------------
#    product_id           created_at                product_name
# 0           1  2012-03-19 08:00:00      The Original Mr. Fuzzy
# 1           2  2013-01-06 13:00:00       The Forever Love Bear
# 2           3  2013-12-12 09:00:00    The Birthday Sugar Panda
# 3           4  2014-02-05 10:00:00  The Hudson River Mini bear
# Shape : (4, 3)
#
# Data Types:
#              Data Type
# product_id       int64
# created_at      object
# product_name    object
# Duplicate:
# np.int64(0)
# Missing Values:
#               Missing Count
# product_id                0
# created_at                0
# product_name              0
# Memory Usage (MB):
# 0.00 MB
#
#
# ------------------------------------------------------------
# ORDERS
# ------------------------------------------------------------
# ...

# %% [markdown]
# #### Transform the create_at column to weekday, day, and month format.
# #### Address missing values within the WEBSITE_SESSIONS dataset.

# %%
for name, df in datasets.items():
    print("-" * 60)
    print(f"Dataset :{name.upper()}" )
    print("-" * 60)
    
    print("\nDescriptive:")
    display(df.describe().T.round(2))
# Out:
# ------------------------------------------------------------
# Dataset :PRODUCTS
# ------------------------------------------------------------
#
# Descriptive:
#             count  mean   std  min   25%  50%   75%  max
# product_id    4.0   2.5  1.29  1.0  1.75  2.5  3.25  4.0
# ------------------------------------------------------------
# Dataset :ORDERS
# ------------------------------------------------------------
#
# Descriptive:
#                       count       mean        std    min        25%        50%        75%        max
# order_id            32313.0   16157.00    9328.10   1.00    8079.00   16157.00   24235.00   32313.00
# website_session_id  32313.0  258292.29  132427.65  20.00  144828.00  263554.00  374799.00  472818.00
# user_id             32313.0  215691.62  108402.20  13.00  124135.00  221461.00  310542.00  394273.00
# primary_product_id  32313.0       1.39       0.73   1.00       1.00       1.00       2.00       4.00
# ...
